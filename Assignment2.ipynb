# %% [markdown]
# <a href="https://colab.research.google.com/github/iqra-ai-engineer/assignment_piaic/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Trainee: Iqra Tahir
# Roll No. PIAIC234522
# Assignment: 2**

# %% [markdown]
# Write a short note (not exceeding 2 lines) on the following topics:

# %% [markdown]
# **API:**
# An Application Programming Interface (API) allows software systems to communicate and exchange data or functionalities effectively.
#
# **SDK:**
#  A Software Development Kit (SDK) is a collection of tools, libraries, and documentation to help developers build applications for specific platforms.
#
# **WEB APIS:**Web APIs are APIs accessible over the web using HTTP, enabling interaction with web services or data.
#
# **Library APIS:**Library APIs provide a set of pre-written functions or methods that developers can use to perform specific tasks in their applications.
#
# **Prompting and Completion:** This refers to providing an input (prompt) to AI models to receive a relevant and context-aware response or output (completion).
